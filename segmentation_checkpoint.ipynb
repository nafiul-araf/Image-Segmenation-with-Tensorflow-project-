# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile
import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import numpy as np

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from matplotlib import pyplot as plt
import seaborn as sns

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.7.0

# %%
class_names=['sky', 'building','column/pole', 'road', 'side walk', 'vegetation', 'traffic light', 'fence', 'vehicle', 
             'pedestrian', 'byciclist', 'void']

# %%
# !ls /content/drive/MyDrive/Image_Segmentation/dataset1
# Out:
# annotations_prepped_test   images_prepped_test
# annotations_prepped_train  images_prepped_train

# %%
# !ls /content/drive/MyDrive/Image_Segmentation/*.py
# Out:
# /content/drive/MyDrive/Image_Segmentation/utility.py

# %%
# !cat '/content/drive/MyDrive/Image_Segmentation/utility.py'
# Out:
# import os
# import zipfile
# import PIL.Image, PIL.ImageFont, PIL.ImageDraw
# import numpy as np
# import tensorflow as tf
# from matplotlib import pyplot as plt
# import seaborn as sns
#
# class_names=['sky', 'building','column/pole', 'road', 'side walk', 'vegetation', 'traffic light', 'fence', 'vehicle',
#              'pedestrian', 'byciclist', 'void']
# def map_filename_to_image_and_mask(t_filename, a_filename, height=224, width=224):
#   '''
#   Preprocesses the dataset by:
#     * resizing the input image and label maps
#     * normalizing the input image pixels
#     * reshaping the label maps from (height, width, 1) to (height, width, 12)
#
#   Args:
#     t_filename (string) -- path to the raw input image
#     a_filename (string) -- path to the raw annotation (label map) file
#     height (int) -- height in pixels to resize to
#     width (int) -- width in pixels to resize to
#
#   Returns:
#     image (tensor) -- preprocessed image
#     annotation (tensor) -- preprocessed annotation
#   '''
#
#   # Convert image and mask files to tensors
#   img_raw = tf.io.read_file(t_filename)
#   anno_raw = tf.io.read_file(a_filename)
#   image = tf.image.decode_jpeg(img_raw)
#   annotation = tf.image.decode_jpeg(anno_raw)
#
#   # Resize image and segmentation mask
#   image = tf.image.resize(image, (height, width,))
#   annotation = tf.image.resize(annotation, (height, width,))
#   image = tf.reshape(image, (height, width, 3,))
#   annotation = tf.cast(annotation, dtype=tf.int32)
#   annotation = tf.reshape(annotation, (height, width, 1,))
#   stack_list = []
#
#   # Reshape segmentation masks
#   for c in range(len(class_names)):
#     mask = tf.equal(annotation[:,:,0], tf.constant(c))
#     stack_list.append(tf.cast(mask, dtype=tf.int32))
#
#   annotation = tf.stack(stack_list, axis=2)
#
#   # Normalize pixels in the input image
#   image = image/127.5
#   image -= 1
#
#   return image, annotation
#
#
# # Utilities for preparing the datasets
#
# BATCH_SIZE = 16
#
# def get_dataset_slice_paths(image_dir, label_map_dir):
#   '''
#   generates the lists of image and label map paths
#
#   Args:
#     image_dir (string) -- path to the input images directory
#     label_map_dir (string) -- path to the label map directory
#
#   Returns:
#     image_paths (list of strings) -- paths to each image file
#     label_map_paths (list of strings) -- paths to each label map
#   '''
#   image_file_list = os.listdir(image_dir)
#   label_map_file_list = os.listdir(label_map_dir)
#   image_paths = [os.path.join(image_dir, fname) for fname in image_file_list]
#   label_map_paths = [os.path.join(label_map_dir, fname) for fname in label_map_file_list]
#
#   return image_paths, label_map_paths
#
#
# def get_training_dataset(image_paths, label_map_paths):
#   '''
#   Prepares shuffled batches of the training set.
#
#   Args:
#     image_paths (list of strings) -- paths to each image file in the train set
#     label_map_paths (list of strings) -- paths to each label map in the train set
#
#   Returns:
#     tf Dataset containing the preprocessed train set
#   '''
#   training_dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_map_paths))
#   training_dataset = training_dataset.map(map_filename_to_image_and_mask)
#   training_dataset = training_dataset.shuffle(100, reshuffle_each_iteration=True)
#   training_dataset = training_dataset.batch(BATCH_SIZE)
#   training_dataset = training_dataset.repeat()
#   training_dataset = training_dataset.prefetch(-1)
#
#   return training_dataset
#
#
# def get_validation_dataset(image_paths, label_map_paths):
#   '''
#   Prepares batches of the validation set.
#
#   Args:
#     image_paths (list of strings) -- paths to each image file in the val set
#     label_map_paths (list of strings) -- paths to each label map in the val set
#
#   Returns:
#     tf Dataset containing the preprocessed validation set
#   '''
#   validation_dataset = tf.data.Dataset.from_tensor_slices((image_paths, label_map_paths))
#   validation_dataset = validation_dataset.map(map_filename_to_image_and_mask)
#   validation_dataset = validation_dataset.batch(BATCH_SIZE)
#   validation_dataset = validation_dataset.repeat()
#
#   return validation_dataset
#
#   # Visualization Utilities
# # generate a list that contains one color for each class
# colors = sns.color_palette(None, len(class_names))
#
# # print class name - normalized RGB tuple pairs
# # the tuple values will be multiplied by 255 in the helper functions later
# # to convert to the (0,0,0) to (255,255,255) RGB values you might be familiar with
# for class_name, color in zip(class_names, colors):
#   print(f'{class_name} -- {color}')
#
#
# def fuse_with_pil(images):
#   '''
#   Creates a blank image and pastes input images
#
#   Args:
#     images (list of numpy arrays) - numpy array representations of the images to paste
#
#   Returns:
#     PIL Image object containing the images
#   '''
#
#   widths = (image.shape[1] for image in images)
#   heights = (image.shape[0] for image in images)
#   total_width = sum(widths)
#   max_height = max(heights)
#
#   new_im = PIL.Image.new('RGB', (total_width, max_height))
#
#   x_offset = 0
#   for im in images:
#     pil_image = PIL.Image.fromarray(np.uint8(im))
#     new_im.paste(pil_image, (x_offset,0))
#     x_offset += im.shape[1]
#
#   return new_im
#
#
# def give_color_to_annotation(annotation):
#   '''
#   Converts a 2-D annotation to a numpy array with shape (height, width, 3) where
#   the third axis represents the color channel. The label values are multiplied by
#   255 and placed in this axis to give color to the annotation
#
#   Args:
#     annotation (numpy array) - label map array
#
#   Returns:
#     the annotation array with an additional color channel/axis
#   '''
#   seg_img = np.zeros( (annotation.shape[0],annotation.shape[1], 3) ).astype('float')
#
#   for c in range(12):
#     segc = (annotation == c)
#     seg_img[:,:,0] += segc*( colors[c][0] * 255.0)
#     seg_img[:,:,1] += segc*( colors[c][1] * 255.0)
#     seg_img[:,:,2] += segc*( colors[c][2] * 255.0)
#
#   return seg_img
#
#
# def show_predictions(image, labelmaps, titles, iou_list, dice_score_list):
#   '''
#   Displays the images with the ground truth and predicted label maps
#
#   Args:
#     image (numpy array) -- the input image
#     labelmaps (list of arrays) -- contains the predicted and ground truth label maps
#     titles (list of strings) -- display headings for the images to be displayed
#     iou_list (list of floats) -- the IOU values for each class
#     dice_score_list (list of floats) -- the Dice Score for each vlass
#   '''
#
#   true_img = give_color_to_annotation(labelmaps[1])
#   pred_img = give_color_to_annotation(labelmaps[0])
#
#   image = image + 1
#   image = image * 127.5
#   images = np.uint8([image, pred_img, true_img])
#
#   metrics_by_id = [(idx, iou, dice_score) for idx, (iou, dice_score) in enumerate(zip(iou_list, dice_score_list)) if iou > 0.0]
#   metrics_by_id.sort(key=lambda tup: tup[1], reverse=True)  # sorts in place
#
#   display_string_list = ["{}: IOU: {} Dice Score: {}".format(class_names[idx], iou, dice_score) for idx, iou, dice_score in metrics_by_id]
#   display_string = "\n\n".join(display_string_list)
#
#   plt.figure(figsize=(15, 4))
#
#   for idx, im in enumerate(images):
#     plt.subplot(1, 3, idx+1)
#     if idx == 1:
#       plt.xlabel(display_string)
#     plt.xticks([])
#     plt.yticks([])
#     plt.title(titles[idx], fontsize=12)
#     plt.imshow(im)
#
#
# def show_annotation_and_image(image, annotation):
#   '''
#   Displays the image and its annotation side by side
#
#   Args:
#     image (numpy array) -- the input image
#     annotation (numpy array) -- the label map
#   '''
#   new_ann = np.argmax(annotation, axis=2)
#   seg_img = give_color_to_annotation(new_ann)
#
#   image = image + 1
#   image = image * 127.5
#   image = np.uint8(image)
#   images = [image, seg_img]
#
#   images = [image, seg_img]
#   fused_img = fuse_with_pil(images)
#   plt.imshow(fused_img)
#
#
# def list_show_annotation(dataset):
#   '''
#   Displays images and its annotations side by side
#
#   Args:
#     dataset (tf Dataset) - batch of images and annotations
#   '''
#
#   ds = dataset.unbatch()
#   ds = ds.shuffle(buffer_size=100)
#
#   plt.figure(figsize=(25, 15))
#   plt.title("Images And Annotations")
#   plt.subplots_adjust(bottom=0.1, top=0.9, hspace=0.05)
#
#   # we set the number of image-annotation pairs to 9
#   # feel free to make this a function parameter if you want
#   for idx, (image, annotation) in enumerate(ds.take(9)):
#     plt.subplot(3, 3, idx + 1)
#     plt.yticks([])
#     plt.xticks([])
#     show_annotation_and_image(image.numpy(), annotation.numpy())

# %%
import sys
sys.path.append('/content/drive/MyDrive/Image_Segmentation')

# %%
import utility
# Out:
# sky -- (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# building -- (1.0, 0.4980392156862745, 0.054901960784313725)
# column/pole -- (0.17254901960784313, 0.6274509803921569, 0.17254901960784313)
# road -- (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)
# side walk -- (0.5803921568627451, 0.403921568627451, 0.7411764705882353)
# vegetation -- (0.5490196078431373, 0.33725490196078434, 0.29411764705882354)
# traffic light -- (0.8901960784313725, 0.4666666666666667, 0.7607843137254902)
# fence -- (0.4980392156862745, 0.4980392156862745, 0.4980392156862745)
# vehicle -- (0.7372549019607844, 0.7411764705882353, 0.13333333333333333)
# pedestrian -- (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)
# byciclist -- (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# void -- (1.0, 0.4980392156862745, 0.054901960784313725)

# %%
from utility import get_dataset_slice_paths, get_training_dataset, get_validation_dataset

# %%
training_image_paths, training_label_map_paths=get_dataset_slice_paths(r'/content/drive/MyDrive/Image_Segmentation/dataset1/images_prepped_train',
                                                                       r'/content/drive/MyDrive/Image_Segmentation/dataset1/annotations_prepped_train')
validation_image_paths, validation_label_map_paths=get_dataset_slice_paths(r'/content/drive/MyDrive/Image_Segmentation/dataset1/images_prepped_test', 
                                                                           r'/content/drive/MyDrive/Image_Segmentation/dataset1/annotations_prepped_test')

# %%
training_dataset=get_training_dataset(training_image_paths, training_label_map_paths)
validation_dataset=get_validation_dataset(validation_image_paths, validation_label_map_paths)

# %%
from utility import list_show_annotation

# %%
list_show_annotation(training_dataset)

# %%
list_show_annotation(validation_dataset)

# %%
def conv2d_block(inputs, filters, kernel_size=(3, 3)):
    x=inputs
    for i in range(2):
        x=tf.keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
                                padding='same', activation='relu')(x)
    
    return x

# %%
def encoder_block(inputs, filters, kernel_size, pool_size, dropout):
    f=conv2d_block(inputs, filters=filters, kernel_size=kernel_size)
    p=tf.keras.layers.MaxPooling2D(pool_size=pool_size)(f)
    p=tf.keras.layers.Dropout(dropout)(p)
    
    return f, p

# %%
def encoder(inputs):
    f1, p1=encoder_block(inputs, filters=64, kernel_size=(3, 3), pool_size=(2, 2), dropout=0.30)
    f2, p2=encoder_block(p1, filters=128, kernel_size=(3, 3), pool_size=(2, 2), dropout=0.30)
    f3, p3=encoder_block(p2, filters=256, kernel_size=(3, 3), pool_size=(2, 2), dropout=0.30)
    f4, p4=encoder_block(p3, filters=512, kernel_size=(3, 3), pool_size=(2, 2), dropout=0.30)
    
    return p4, (f1, f2, f3, f4)

# %%
def bottleneck_block(inputs):
    b=conv2d_block(inputs, filters=1024)
    
    return b

# %%
def decoder_block(inputs, conv_outputs, filters, kernel_size, strides, dropout):
    u=tf.keras.layers.Conv2DTranspose(filters=filters, kernel_size=kernel_size, strides=strides, padding='same')(inputs)
    c=tf.keras.layers.concatenate([u, conv_outputs])
    d=tf.keras.layers.Dropout(dropout)(c)
    l=conv2d_block(d, filters=filters, kernel_size=kernel_size)
    
    return l

# %%
def decoder(inputs, con_outs, output_channels):
    f1, f2, f3, f4=con_outs
    
    d1=decoder_block(inputs, conv_outputs=f4, filters=512, kernel_size=(3, 3), strides=(2, 2), dropout=0.3)
    d2=decoder_block(d1, conv_outputs=f3, filters=256, kernel_size=(3, 3), strides=(2, 2), dropout=0.3)
    d3=decoder_block(d2, conv_outputs=f2, filters=128, kernel_size=(3, 3), strides=(2, 2), dropout=0.3)
    d4=decoder_block(d3, conv_outputs=f1, filters=64, kernel_size=(3, 3), strides=(2, 2), dropout=0.3)
    
    outputs=tf.keras.layers.Conv2D(output_channels, kernel_size=(1, 1), activation='softmax')(d4)
    
    return outputs

# %%
def unet_model():
    inputs=tf.keras.layers.Input(shape=(224, 224, 3))
    encoder_output, convs=encoder(inputs)
    bottleneck=bottleneck_block(encoder_output)
    decoder_output=decoder(bottleneck, convs, 12)
    
    model=tf.keras.Model(inputs=inputs, outputs=decoder_output)
    
    return model

model=unet_model()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 112, 112, 64  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['dropout[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 56, 56, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  295168      ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 28, 28, 256)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 512)  1180160     ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 14, 14, 512)  0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 1024  4719616     ['dropout_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 1024  9438208     ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 512)  4719104    ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 28, 28, 1024  0           ['concatenate[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 512)  4719104     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 512)  2359808     ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 256)  1179904    ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 56, 56, 512)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 256)  1179904     ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 256)  590080      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 12  295040     ['conv2d_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 112, 112, 25  0           ['concatenate_2[0][0]']
#                                 6)
#
#  conv2d_14 (Conv2D)             (None, 112, 112, 12  295040      ['dropout_6[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 112, 112, 12  147584      ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 64  73792      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 224, 224, 12  0           ['concatenate_3[0][0]']
#                                 8)
#
#  conv2d_16 (Conv2D)             (None, 224, 224, 64  73792       ['dropout_7[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 224, 224, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 224, 224, 12  780         ['conv2d_17[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 34,514,060
# Trainable params: 34,514,060
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=tf.keras.optimizers.SGD(lr=1E-2, momentum=0.9, nesterov=True), 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
from glob import glob
data_train=r'/content/drive/MyDrive/Image_Segmentation/dataset1/images_prepped_train/*.png'
data_val=r'/content/drive/MyDrive/Image_Segmentation/dataset1/images_prepped_test/*.png'
print('Total Training Images: {}'.format(len(list(glob(data_train)))))
print('\nTotal Validation Images: {}'.format(len(list(glob(data_val)))))
# Out:
# Total Training Images: 367
#
# Total Validation Images: 101

# %%
train_data=367
val_data=101
BATCH_SIZE=16
history = model.fit(training_dataset, steps_per_epoch=train_data//BATCH_SIZE, validation_data=validation_dataset, 
                    validation_steps=val_data//BATCH_SIZE, epochs=200)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 68s 2s/step - loss: 1.9488 - accuracy: 0.3870 - val_loss: 1.7944 - val_accuracy: 0.3808
# Epoch 2/200
# 22/22 [==============================] - 54s 2s/step - loss: 1.7400 - accuracy: 0.4532 - val_loss: 1.7141 - val_accuracy: 0.3938
# Epoch 3/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.6290 - accuracy: 0.4826 - val_loss: 1.8076 - val_accuracy: 0.3862
# Epoch 4/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.6257 - accuracy: 0.4868 - val_loss: 1.8761 - val_accuracy: 0.3805
# Epoch 5/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.5270 - accuracy: 0.5119 - val_loss: 1.7849 - val_accuracy: 0.3955
# Epoch 6/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.4653 - accuracy: 0.5303 - val_loss: 1.8564 - val_accuracy: 0.4024
# Epoch 7/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.4220 - accuracy: 0.5440 - val_loss: 2.2958 - val_accuracy: 0.3679
# Epoch 8/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.4121 - accuracy: 0.5428 - val_loss: 1.9467 - val_accuracy: 0.4206
# Epoch 9/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.3411 - accuracy: 0.5670 - val_loss: 1.9948 - val_accuracy: 0.4162
# Epoch 10/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.3473 - accuracy: 0.5611 - val_loss: 1.9980 - val_accuracy: 0.4087
# Epoch 11/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.3280 - accuracy: 0.5684 - val_loss: 1.9741 - val_accuracy: 0.4147
# Epoch 12/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.3122 - accuracy: 0.5691 - val_loss: 1.9660 - val_accuracy: 0.4270
# Epoch 13/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.2972 - accuracy: 0.5751 - val_loss: 1.9892 - val_accuracy: 0.4380
# Epoch 14/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.2792 - accuracy: 0.5795 - val_loss: 2.1883 - val_accuracy: 0.4076
# Epoch 15/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.
200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1271 - accuracy: 0.6185 - val_loss: 1.5179 - val_accuracy: 0.5301
# Epoch 105/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1284 - accuracy: 0.6204 - val_loss: 1.3898 - val_accuracy: 0.5319
# Epoch 106/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1261 - accuracy: 0.6188 - val_loss: 1.5077 - val_accuracy: 0.5117
# Epoch 107/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1295 - accuracy: 0.6197 - val_loss: 1.3216 - val_accuracy: 0.5443
# Epoch 108/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1343 - accuracy: 0.6143 - val_loss: 1.4535 - val_accuracy: 0.5192
# Epoch 109/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1316 - accuracy: 0.6181 - val_loss: 1.4140 - val_accuracy: 0.5348
# Epoch 110/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1274 - accuracy: 0.6202 - val_loss: 1.3237 - val_accuracy: 0.5534
# Epoch 111/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1322 - accuracy: 0.6161 - val_loss: 1.3851 - val_accuracy: 0.5412
# Epoch 112/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1235 - accuracy: 0.6203 - val_loss: 1.4888 - val_accuracy: 0.5385
# Epoch 113/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1291 - accuracy: 0.6177 - val_loss: 1.4896 - val_accuracy: 0.5268
# Epoch 114/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1246 - accuracy: 0.6195 - val_loss: 1.3992 - val_accuracy: 0.5461
# Epoch 115/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1209 - accuracy: 0.6207 - val_loss: 1.3374 - val_accuracy: 0.5511
# Epoch 116/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1269 - accuracy: 0.6176 - val_loss: 1.5029 - val_accuracy: 0.5184
# Epoch 117/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1340 - accuracy: 0.6159 - val_loss: 1.3148 - val_accuracy: 0.5542
# Epoch 118/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1134 - accuracy: 0.6254 - val_loss: 1.4760 - val_accuracy: 0.5317
# Epoch 119/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1216 - accuracy: 0.6182 - val_loss: 1.4300 - val_accuracy: 0.5447
# Epoch 120/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1246 - accuracy: 0.6189 - val_loss: 1.4287 - val_accuracy: 0.5530
# Epoch 121/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1241 - accuracy: 0.6197 - val_loss: 1.3575 - val_accuracy: 0.5500
# Epoch 122/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1277 - accuracy: 0.6159 - val_loss: 1.4501 - val_accuracy: 0.5301
# Epoch 123/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1208 - accuracy: 0.6177 - val_loss: 1.3938 - val_accuracy: 0.5446
# Epoch 124/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1027 - accuracy: 0.6270 - val_loss: 1.3861 - val_accuracy: 0.5389
# Epoch 125/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1388 - accuracy: 0.6116 - val_loss: 1.3789 - val_accuracy: 0.5492
# Epoch 126/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1166 - accuracy: 0.6204 - val_loss: 1.5406 - val_accuracy: 0.5393
# Epoch 127/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1077 - accuracy: 0.6252 - val_loss: 1.4397 - val_accuracy: 0.5400
# Epoch 128/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1242 - accuracy: 0.6194 - val_loss: 1.5486 - val_accuracy: 0.5317
# Epoch 129/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1167 - accuracy: 0.6208 - val_loss: 1.4404 - val_accuracy: 0.5378
# Epoch 130/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1212 - accuracy: 0.6150 - val_loss: 1.3303 - val_accuracy: 0.5589
# Epoch 131/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1168 - accuracy: 0.6200 - val_loss: 1.3372 - val_accuracy: 0.5593
# Epoch 132/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1186 - accuracy: 0.6201 - val_loss: 1.3289 - val_accuracy: 0.5566
# Epoch 133/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1179 - accuracy: 0.6212 - val_loss: 1.2766 - val_accuracy: 0.5555
# Epoch 134/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1151 - accuracy: 0.6205 - val_loss: 1.4198 - val_accuracy: 0.5523
# Epoch 135/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1163 - accuracy: 0.6207 - val_loss: 1.4037 - val_accuracy: 0.5423
# Epoch 136/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1178 - accuracy: 0.6199 - val_loss: 1.3733 - val_accuracy: 0.5477
# Epoch 137/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1017 - accuracy: 0.6255 - val_loss: 1.4271 - val_accuracy: 0.5483
# Epoch 138/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1213 - accuracy: 0.6189 - val_loss: 1.4142 - val_accuracy: 0.5436
# Epoch 139/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1161 - accuracy: 0.6198 - val_loss: 1.4037 - val_accuracy: 0.5396
# Epoch 140/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1080 - accuracy: 0.6224 - val_loss: 1.2886 - val_accuracy: 0.5585
# Epoch 141/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1137 - accuracy: 0.6201 - val_loss: 1.3525 - val_accuracy: 0.5512
# Epoch 142/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1109 - accuracy: 0.6220 - val_loss: 1.3489 - val_accuracy: 0.5567
# Epoch 143/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1043 - accuracy: 0.6249 - val_loss: 1.3339 - val_accuracy: 0.5463
# Epoch 144/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1085 - accuracy: 0.6221 - val_loss: 1.5204 - val_accuracy: 0.5240
# Epoch 145/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1111 - accuracy: 0.6221 - val_loss: 1.4677 - val_accuracy: 0.5308
# Epoch 146/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1105 - accuracy: 0.6224 - val_loss: 1.4476 - val_accuracy: 0.5320
# Epoch 147/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1133 - accuracy: 0.6202 - val_loss: 1.3721 - val_accuracy: 0.5528
# Epoch 148/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1025 - accuracy: 0.6259 - val_loss: 1.3476 - val_accuracy: 0.5510
# Epoch 149/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1083 - accuracy: 0.6205 - val_loss: 1.3633 - val_accuracy: 0.5494
# Epoch 150/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1072 - accuracy: 0.6239 - val_loss: 1.5755 - val_accuracy: 0.5248
# Epoch 151/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1203 - accuracy: 0.6158 - val_loss: 1.5536 - val_accuracy: 0.5316
# Epoch 152/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0949 - accuracy: 0.6269 - val_loss: 1.4332 - val_accuracy: 0.5389
# Epoch 153/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1075 - accuracy: 0.6232 - val_loss: 1.2848 - val_accuracy: 0.5522
# Epoch 154/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1132 - accuracy: 0.6176 - val_loss: 1.3778 - val_accuracy: 0.5399
# Epoch 155/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1068 - accuracy: 0.6212 - val_loss: 1.3483 - val_accuracy: 0.5564
# Epoch 156/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0952 - accuracy: 0.6272 - val_loss: 1.3776 - val_accuracy: 0.5448
# Epoch 157/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1083 - accuracy: 0.6237 - val_loss: 1.3375 - val_accuracy: 0.5581
# Epoch 158/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1047 - accuracy: 0.6237 - val_loss: 1.3235 - val_accuracy: 0.5578
# Epoch 159/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1076 - accuracy: 0.6204 - val_loss: 1.3912 - val_accuracy: 0.5571
# Epoch 160/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1089 - accuracy: 0.6220 - val_loss: 1.3928 - val_accuracy: 0.5472
# Epoch 161/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0981 - accuracy: 0.6258 - val_loss: 1.4443 - val_accuracy: 0.5235
# Epoch 162/200
# 22/22 [==============================] - 35s 2s/step - loss: 1.1010 - accuracy: 0.6242 - val_loss: 1.2866 - val_accuracy: 0.5545
# Epoch 163/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1093 - accuracy: 0.6206 - val_loss: 1.3461 - val_accuracy: 0.5463
# Epoch 164/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0889 - accuracy: 0.6286 - val_loss: 1.3764 - val_accuracy: 0.5459
# Epoch 165/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1032 - accuracy: 0.6212 - val_loss: 1.3893 - val_accuracy: 0.5406
# Epoch 166/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1059 - accuracy: 0.6209 - val_loss: 1.3006 - val_accuracy: 0.5498
# Epoch 167/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0916 - accuracy: 0.6304 - val_loss: 1.3646 - val_accuracy: 0.5446
# Epoch 168/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0946 - accuracy: 0.6249 - val_loss: 1.4290 - val_accuracy: 0.5301
# Epoch 169/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0999 - accuracy: 0.6236 - val_loss: 1.3375 - val_accuracy: 0.5522
# Epoch 170/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1026 - accuracy: 0.6230 - val_loss: 1.3867 - val_accuracy: 0.5431
# Epoch 171/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1035 - accuracy: 0.6203 - val_loss: 1.3655 - val_accuracy: 0.5217
# Epoch 172/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0961 - accuracy: 0.6247 - val_loss: 1.3169 - val_accuracy: 0.5507
# Epoch 173/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0932 - accuracy: 0.6284 - val_loss: 1.4808 - val_accuracy: 0.5391
# Epoch 174/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1051 - accuracy: 0.6224 - val_loss: 1.3181 - val_accuracy: 0.5610
# Epoch 175/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0891 - accuracy: 0.6294 - val_loss: 1.3683 - val_accuracy: 0.5466
# Epoch 176/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1059 - accuracy: 0.6221 - val_loss: 1.3001 - val_accuracy: 0.5534
# Epoch 177/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0968 - accuracy: 0.6233 - val_loss: 1.3652 - val_accuracy: 0.5445
# Epoch 178/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0915 - accuracy: 0.6260 - val_loss: 1.3185 - val_accuracy: 0.5633
# Epoch 179/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0974 - accuracy: 0.6229 - val_loss: 1.4433 - val_accuracy: 0.5368
# Epoch 180/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0925 - accuracy: 0.6286 - val_loss: 1.3779 - val_accuracy: 0.5501
# Epoch 181/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0942 - accuracy: 0.6251 - val_loss: 1.2992 - val_accuracy: 0.5638
# Epoch 182/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0892 - accuracy: 0.6270 - val_loss: 1.4555 - val_accuracy: 0.5437
# Epoch 183/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0925 - accuracy: 0.6266 - val_loss: 1.5174 - val_accuracy: 0.4975
# Epoch 184/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0888 - accuracy: 0.6279 - val_loss: 1.3231 - val_accuracy: 0.5568
# Epoch 185/200
# 22/22 [==============================] - 35s 2s/step - loss: 1.0936 - accuracy: 0.6266 - val_loss: 1.4530 - val_accuracy: 0.5349
# Epoch 186/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0863 - accuracy: 0.6261 - val_loss: 1.3950 - val_accuracy: 0.5496
# Epoch 187/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0908 - accuracy: 0.6274 - val_loss: 1.2649 - val_accuracy: 0.5670
# Epoch 188/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0840 - accuracy: 0.6275 - val_loss: 1.3123 - val_accuracy: 0.5571
# Epoch 189/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0848 - accuracy: 0.6300 - val_loss: 1.3760 - val_accuracy: 0.5484
# Epoch 190/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0862 - accuracy: 0.6279 - val_loss: 1.4207 - val_accuracy: 0.5332
# Epoch 191/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0915 - accuracy: 0.6266 - val_loss: 1.3388 - val_accuracy: 0.5525
# Epoch 192/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0832 - accuracy: 0.6274 - val_loss: 1.3597 - val_accuracy: 0.5596
# Epoch 193/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0852 - accuracy: 0.6267 - val_loss: 1.4997 - val_accuracy: 0.5234
# Epoch 194/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0895 - accuracy: 0.6261 - val_loss: 1.2656 - val_accuracy: 0.5610
# Epoch 195/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0824 - accuracy: 0.6326 - val_loss: 1.5092 - val_accuracy: 0.5336
# Epoch 196/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0804 - accuracy: 0.6287 - val_loss: 1.2869 - val_accuracy: 0.5542
# Epoch 197/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0828 - accuracy: 0.6306 - val_loss: 1.2899 - val_accuracy: 0.5598
# Epoch 198/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.1005 - accuracy: 0.6207 - val_loss: 1.4158 - val_accuracy: 0.5154
# Epoch 199/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0756 - accuracy: 0.6313 - val_loss: 1.3578 - val_accuracy: 0.5486
# Epoch 200/200
# 22/22 [==============================] - 34s 2s/step - loss: 1.0808 - accuracy: 0.6327 - val_loss: 1.4867 - val_accuracy: 0.5271

# %%
def true_img_segments():
  true_images=[]
  true_segments=[]
  test_data=50
  data=validation_dataset.unbatch()
  data=data.batch(101)

  for image, segment in data.take(1):
    true_images=image
    true_segments=segment
  
  true_segments=true_segments[:test_data, :, :, :]
  true_segments=np.argmax(true_segments, axis=3)

  return true_images, true_segments

true_images, true_segments=true_img_segments()

# %%
predictions=model.predict(validation_dataset, steps=val_data//BATCH_SIZE)
predictions=np.argmax(predictions, axis=3)

# %%
def evaluation_metrics(y_true, y_pred):
  iou_score=[]
  dice_score=[]
  smoothing_factor=0.00001

  for i in range(12):
    y_true_area=np.sum(y_true==i)
    y_pred_area=np.sum(y_pred==i)
    intersect_area=np.sum(y_pred_area*y_true_area)
    combined_area=y_true_area+y_pred_area

    iou=(intersect_area+smoothing_factor)/(combined_area-intersect_area+smoothing_factor)
    iou_score.append(iou)

    dice=2*((intersect_area+smoothing_factor)/(combined_area+smoothing_factor))
    dice_score.append(dice_score)
  
  return iou_score, dice_score

# %%
iou_score, dice_score=evaluation_metrics(true_segments[0], predictions[0])

# %%
from utility import show_predictions

# %%
show_predictions(true_images[0], [predictions[0], true_segments[0]], ['Images', 'Predicted Segmentation', 'True Segmentation'], iou_score, dice_score)

# %%
iou_class, dice_class=evaluation_metrics(true_segments, predictions)

for index, iou in enumerate(iou_class):
  x=' '*(13-len(class_names[index])+2)
  print("{}{}{} ".format(class_names[index], x, iou))
# Out:
# sky            -1.0000055076222012
# building       -1.0000023454467302
# column/pole    6.098304667582447e-10
# road           -1.0000017905335208
# side walk      -1.0000652731321433
# vegetation     -1.0000111257323796
# traffic light  4.184800801730499e-10
# fence          1.348708611322583e-10
# vehicle        -1.000022753165784
# pedestrian     5.678914188381559e-10
# byciclist      1.96105347754377e-10
# void           -1.000134493126186

# %%
for index, dice in enumerate(dice_class):
  x=' '*(13-len(class_names[index])+2)
  print("{}{}{} ".format(class_names[index], x, dice))
# Out:
# sky            [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# building       [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# column/pole    [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# road           [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# side walk      [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# vegetation     [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# traffic light  [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# fence          [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# vehicle        [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# pedestrian     [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# byciclist      [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
# void           [[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...]]
